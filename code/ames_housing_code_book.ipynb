# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Import-Packages" data-toc-modified-id="1.-Import-Packages-1">1. Import Packages</a></span></li><li><span><a href="#2.-Read-in-Data" data-toc-modified-id="2.-Read-in-Data-2">2. Read in Data</a></span><ul class="toc-item"><li><span><a href="#Options-Setting" data-toc-modified-id="Options-Setting-2.1">Options Setting</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Initial-Checks" data-toc-modified-id="Initial-Checks-2.1.0.1">Initial Checks</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#3.-Data-Cleaning" data-toc-modified-id="3.-Data-Cleaning-3">3. Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Features-Dictionary" data-toc-modified-id="Features-Dictionary-3.1">Features Dictionary</a></span></li><li><span><a href="#Exploring-and-Fixing-Nulls" data-toc-modified-id="Exploring-and-Fixing-Nulls-3.2">Exploring and Fixing Nulls</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Masonry-Veneer-Type" data-toc-modified-id="Masonry-Veneer-Type-3.2.0.1">Masonry Veneer Type</a></span></li><li><span><a href="#Electrical" data-toc-modified-id="Electrical-3.2.0.2">Electrical</a></span></li><li><span><a href="#Filling-Other-Nulls" data-toc-modified-id="Filling-Other-Nulls-3.2.0.3">Filling Other Nulls</a></span></li></ul></li></ul></li><li><span><a href="#Exploring-and-Fixing-Data-Types" data-toc-modified-id="Exploring-and-Fixing-Data-Types-3.3">Exploring and Fixing Data Types</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#MS-SubClass" data-toc-modified-id="MS-SubClass-3.3.0.1">MS SubClass</a></span></li><li><span><a href="#PID" data-toc-modified-id="PID-3.3.0.2">PID</a></span></li></ul></li></ul></li><li><span><a href="#Numerical-Values:-Outliers-and-Others" data-toc-modified-id="Numerical-Values:-Outliers-and-Others-3.4">Numerical Values: Outliers and Others</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Above-Ground-Living-Area" data-toc-modified-id="Above-Ground-Living-Area-3.4.0.1">Above Ground Living Area</a></span></li><li><span><a href="#Lot-Frontage" data-toc-modified-id="Lot-Frontage-3.4.0.2">Lot Frontage</a></span></li><li><span><a href="#Lot-Area" data-toc-modified-id="Lot-Area-3.4.0.3">Lot Area</a></span></li><li><span><a href="#Overall-Quality-and-Condition" data-toc-modified-id="Overall-Quality-and-Condition-3.4.0.4">Overall Quality and Condition</a></span></li><li><span><a href="#Year-Built" data-toc-modified-id="Year-Built-3.4.0.5">Year Built</a></span></li><li><span><a href="#Year-Remodeled" data-toc-modified-id="Year-Remodeled-3.4.0.6">Year Remodeled</a></span></li><li><span><a href="#Month-Sold" data-toc-modified-id="Month-Sold-3.4.0.7">Month Sold</a></span></li><li><span><a href="#Year-Sold" data-toc-modified-id="Year-Sold-3.4.0.8">Year Sold</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#4.-Initial-Data-Analysis" data-toc-modified-id="4.-Initial-Data-Analysis-4">4. Initial Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Initial-EDA" data-toc-modified-id="Initial-EDA-4.1">Initial EDA</a></span></li></ul></li><li><span><a href="#5.-Feature-Engineering" data-toc-modified-id="5.-Feature-Engineering-5">5. Feature Engineering</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Dummy-Variables" data-toc-modified-id="Dummy-Variables-5.0.1">Dummy Variables</a></span></li><li><span><a href="#Ordinal-Features" data-toc-modified-id="Ordinal-Features-5.0.2">Ordinal Features</a></span></li><li><span><a href="#Interaction-Features-and-Other-Additions/Subtractions" data-toc-modified-id="Interaction-Features-and-Other-Additions/Subtractions-5.0.3">Interaction Features and Other Additions/Subtractions</a></span></li></ul></li></ul></li><li><span><a href="#6.--Correlations-&amp;-Additional-Feature-Engineering" data-toc-modified-id="6.--Correlations-&amp;-Additional-Feature-Engineering-6">6.  Correlations &amp; Additional Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Correlation-Heat-Maps" data-toc-modified-id="Correlation-Heat-Maps-6.1">Correlation Heat Maps</a></span><ul class="toc-item"><li><span><a href="#Sale-Price" data-toc-modified-id="Sale-Price-6.1.1">Sale Price</a></span></li><li><span><a href="#Lot-Area" data-toc-modified-id="Lot-Area-6.1.2">Lot Area</a></span></li><li><span><a href="#Above-Ground-Living-Area" data-toc-modified-id="Above-Ground-Living-Area-6.1.3">Above Ground Living Area</a></span></li><li><span><a href="#Neighborhood-Analysis" data-toc-modified-id="Neighborhood-Analysis-6.1.4">Neighborhood Analysis</a></span></li><li><span><a href="#Home-Quality-Analysis" data-toc-modified-id="Home-Quality-Analysis-6.1.5">Home Quality Analysis</a></span></li></ul></li></ul></li><li><span><a href="#7.-Modeling" data-toc-modified-id="7.-Modeling-7">7. Modeling</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-7.1">Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Error-Regression-Plot" data-toc-modified-id="Error-Regression-Plot-7.1.1">Error Regression Plot</a></span></li><li><span><a href="#Beta-Coefficient-Analysis" data-toc-modified-id="Beta-Coefficient-Analysis-7.1.2">Beta Coefficient Analysis</a></span></li></ul></li><li><span><a href="#Lasso-Regression" data-toc-modified-id="Lasso-Regression-7.2">Lasso Regression</a></span><ul class="toc-item"><li><span><a href="#Error-Regression-Plot" data-toc-modified-id="Error-Regression-Plot-7.2.1">Error Regression Plot</a></span></li></ul></li><li><span><a href="#Ridge-Regression" data-toc-modified-id="Ridge-Regression-7.3">Ridge Regression</a></span><ul class="toc-item"><li><span><a href="#Error-Regression-Plot" data-toc-modified-id="Error-Regression-Plot-7.3.1">Error Regression Plot</a></span></li><li><span><a href="#Baseline-Model" data-toc-modified-id="Baseline-Model-7.3.2">Baseline Model</a></span></li><li><span><a href="#Final-Model-Selection" data-toc-modified-id="Final-Model-Selection-7.3.3">Final Model Selection</a></span><ul class="toc-item"><li><span><a href="#Kaggle-Submission" data-toc-modified-id="Kaggle-Submission-7.3.3.1">Kaggle Submission</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#8.-Conclusions-and-Recommendation" data-toc-modified-id="8.-Conclusions-and-Recommendation-8">8. Conclusions and Recommendation</a></span></li></ul></div>

# %% [markdown]
# # 1. Import Packages

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV

# %matplotlib inline

# %% [markdown]
# # 2. Read in Data

# %%
df_train = pd.read_csv('../datasets/train.csv')
df_test = pd.read_csv('../datasets/test.csv')

# %% [markdown]
# ## Options Setting

# %%
pd.options.display.max_rows = 300

# %%
pd.set_option('display.max_columns', 999)

# %%
df_train.set_index('Id', inplace = True)

# %%
df_test.set_index('Id', inplace = True)

# %% [markdown]
# #### Initial Checks

# %%
df_train.shape
# Out:
# (2051, 80)

# %%
df_test.shape
# Out:
# (879, 79)

# %%
df_train.head()
# Out:
#            PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 109  533352170           60        RL           NaN     13517   Pave   NaN
# 544  531379050           60        RL          43.0     11492   Pave   NaN
# 153  535304180           20        RL          68.0      7922   Pave   NaN
# 318  916386060           60        RL          73.0      9802   Pave   NaN
# 255  906425045           50        RL          82.0     14235   Pave   NaN
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# Id
# 109       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 544       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 153       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 318       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 255       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df_train.dtypes
# Out:
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# BsmtFin Type 1      object
# ...

# %%
df_train.isnull().sum()
# Out:
# PID                   0
# MS SubClass           0
# MS Zoning             0
# Lot Frontage        330
# Lot Area              0
# Street                0
# Alley              1911
# Lot Shape             0
# Land Contour          0
# Utilities             0
# Lot Config            0
# Land Slope            0
# Neighborhood          0
# Condition 1           0
# Condition 2           0
# Bldg Type             0
# House Style           0
# Overall Qual          0
# Overall Cond          0
# Year Built            0
# Year Remod/Add        0
# Roof Style            0
# Roof Matl             0
# Exterior 1st          0
# Exterior 2nd          0
# Mas Vnr Type         22
# Mas Vnr Area         22
# Exter Qual            0
# Exter Cond            0
# Foundation            0
# Bsmt Qual            55
# Bsmt Cond            55
# Bsmt Exposure        58
# BsmtFin Type 1       55
# BsmtFin SF 1          1
# BsmtFin Type 2       56
# BsmtFin SF 2          1
# Bsmt Unf SF           1
# ...

# %%
# box plot on sale price for train and test data
sns.boxplot(df_train['SalePrice']);

# %%
df_test.shape
# Out:
# (879, 79)

# %%
# additionally, we want to have lower case column titles with no spaces
df_train.columns = df_train.columns.str.lower().str.replace(" ", "_")
df_test.columns = df_test.columns.str.lower().str.replace(" ", "_")

# %% [markdown]
# # 3. Data Cleaning

# %%
df_train.head()
# Out:
#            pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# Id
# 109  533352170           60        RL           NaN     13517   Pave   NaN
# 544  531379050           60        RL          43.0     11492   Pave   NaN
# 153  535304180           20        RL          68.0      7922   Pave   NaN
# 318  916386060           60        RL          73.0      9802   Pave   NaN
# 255  906425045           50        RL          82.0     14235   Pave   NaN
#
#     lot_shape land_contour utilities lot_config land_slope neighborhood  \
# Id
# 109       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 544       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 153       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 318       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 255       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %% [markdown]
# ## Features Dictionary

# %%
features_dict = {'nominal' : ['ms_subclass', 'ms_zoning', 'street', 'alley', 'land_contour', 'lot_config',
                             'neighborhood', 'condition_1', 'condition_2', 'bldg_type', 'house_style',
                             'roof_style', 'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type', 
                             'foundation', 'heating', 'central_air', 'garage_type', 
                             'sale_type'],
                'ordinal' : ['lot_shape', 'utilities', 'land_slope', 'overall_qual', 'overall_cond', 'exter_qual',
                            'exter_cond', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1',
                            'bsmtfin_type_2', 'heating_qc', 'electrical', 'kitchen_qual', 'functional',
                            'fireplace_qu', 'garage_finish', 'garage_qual', 'garage_cond', 'paved_drive', 'pool_qc',
                            'fence'],
                'discrete' : ['year_built', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath', 'half_bath',
                             'bedroom_abvgr', 'kitchen_abvgr', 'totrms_abvgrd', 'fireplaces', 'garage_yr_blt', 'garage_cars',
                             'mo_sold', 'yr_sold'],
                'continuous' : ['lot_frontage', 'lot_area', 'mas_vnr_area', 'bsmtfin_sf_1', 'bsmtfin_sf_2',
                               'bsmt_unf_sf', 'total_bsmt_sf', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
                               'gr_liv_area', 'garage_area', 'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', 
                               '3ssn_porch', 'screen_porch', 'pool_area', 'misc_val'],
                'target' : ['SalePrice']}

# %% [markdown]
# ## Exploring and Fixing Nulls

# %%
df_train.isnull().sum()
# Out:
# pid                   0
# ms_subclass           0
# ms_zoning             0
# lot_frontage        330
# lot_area              0
# street                0
# alley              1911
# lot_shape             0
# land_contour          0
# utilities             0
# lot_config            0
# land_slope            0
# neighborhood          0
# condition_1           0
# condition_2           0
# bldg_type             0
# house_style           0
# overall_qual          0
# overall_cond          0
# year_built            0
# year_remod/add        0
# roof_style            0
# roof_matl             0
# exterior_1st          0
# exterior_2nd          0
# mas_vnr_type         22
# mas_vnr_area         22
# exter_qual            0
# exter_cond            0
# foundation            0
# bsmt_qual            55
# bsmt_cond            55
# bsmt_exposure        58
# bsmtfin_type_1       55
# bsmtfin_sf_1          1
# bsmtfin_type_2       56
# bsmtfin_sf_2          1
# bsmt_unf_sf           1
# ...

# %%
df_test.isnull().sum()
# Out:
# pid                  0
# ms_subclass          0
# ms_zoning            0
# lot_frontage       160
# lot_area             0
# street               0
# alley              821
# lot_shape            0
# land_contour         0
# utilities            0
# lot_config           0
# land_slope           0
# neighborhood         0
# condition_1          0
# condition_2          0
# bldg_type            0
# house_style          0
# overall_qual         0
# overall_cond         0
# year_built           0
# year_remod/add       0
# roof_style           0
# roof_matl            0
# exterior_1st         0
# exterior_2nd         0
# mas_vnr_type         1
# mas_vnr_area         1
# exter_qual           0
# exter_cond           0
# foundation           0
# bsmt_qual           25
# bsmt_cond           25
# bsmt_exposure       25
# bsmtfin_type_1      25
# bsmtfin_sf_1         0
# bsmtfin_type_2      25
# bsmtfin_sf_2         0
# bsmt_unf_sf          0
# total_bsmt_sf        0
# heating              0
# ...

# %% [markdown]
# After doing an examination of the various null values, we can conclude that all Nominal and Ordinal nulls can be converted to 'NA' and all discrete and continuous feature nulls can be converted to 0.  One exception is with Masonry Veneer Type, which has a zero value of None, not NA.  The second exception is with the null in Electrical for the test data. Unfortunately here, we do have to make some assumptions on the electrical system for this home.  Given that the heating systtem is good (2nd best), I will assign this home with the Fuse A electrical system, the second best version.  Please note the following features will have nulls converted:
#
# Lot Frontage
# Alley
# Mas Vnr Type
# Mas Vnr Area
# Bsmt Qual
# Bsmt Cond
# Bsmt Exposure
# BsmtFin Type 1
# BsmtFin Type 2
# Electrical
# Fireplace Qu
# Garage Type
# Garage Yr Blt
# Garage Finish
# Garage Qual
# Garage Cond
# Pool QC
# Fence
# Misc Feature

# %% [markdown]
# #### Masonry Veneer Type

# %%
df_train['mas_vnr_type']
# Out:
# Id
# 109     BrkFace
# 544     BrkFace
# 153        None
# 318        None
# 255        None
#          ...
# 1587       None
# 785        None
# 916        None
# 639        None
# 10         None
# Name: mas_vnr_type, Length: 2051, dtype: object

# %%
# train data fill na
df_train['mas_vnr_type'].fillna('None', inplace = True)
# test data fill na
df_test['mas_vnr_type'].fillna('None', inplace = True)

# %% [markdown]
# #### Electrical

# %%
df_test.loc[df_test['electrical'].isnull(), ['electrical']] = 'FuseA'

# %% [markdown]
# #### Filling Other Nulls

# %% [markdown]
# For the rest of the nulls, it can be gathered that the numeric columns will be filled with 0s and the object columns will be filled with NA string.

# %%
df_train.dtypes
# Out:
# pid                  int64
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# roof_style          object
# roof_matl           object
# exterior_1st        object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_qual           object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# ...

# %%
# code to replace object nulls with NA and numeric nulls with 0
df_train = df_train.apply(lambda x: x.fillna('NA') if x.dtype == object else x.fillna(0))
df_test = df_test.apply(lambda x: x.fillna('NA') if x.dtype == object else x.fillna(0))

# %% [markdown]
# This column can be removed as the value in it is captured by the Misc Val column.

# %%
# train dropping column

df_train.drop(columns = ['misc_feature'], inplace = True)

# test dropping column
df_test.drop(columns = ['misc_feature'], inplace = True)

# %%
df_train.isnull().sum()
# Out:
# pid                0
# ms_subclass        0
# ms_zoning          0
# lot_frontage       0
# lot_area           0
# street             0
# alley              0
# lot_shape          0
# land_contour       0
# utilities          0
# lot_config         0
# land_slope         0
# neighborhood       0
# condition_1        0
# condition_2        0
# bldg_type          0
# house_style        0
# overall_qual       0
# overall_cond       0
# year_built         0
# year_remod/add     0
# roof_style         0
# roof_matl          0
# exterior_1st       0
# exterior_2nd       0
# mas_vnr_type       0
# mas_vnr_area       0
# exter_qual         0
# exter_cond         0
# foundation         0
# bsmt_qual          0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       0
# bsmtfin_type_2     0
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         0
# ...

# %%
df_test.isnull().sum()
# Out:
# pid                0
# ms_subclass        0
# ms_zoning          0
# lot_frontage       0
# lot_area           0
# street             0
# alley              0
# lot_shape          0
# land_contour       0
# utilities          0
# lot_config         0
# land_slope         0
# neighborhood       0
# condition_1        0
# condition_2        0
# bldg_type          0
# house_style        0
# overall_qual       0
# overall_cond       0
# year_built         0
# year_remod/add     0
# roof_style         0
# roof_matl          0
# exterior_1st       0
# exterior_2nd       0
# mas_vnr_type       0
# mas_vnr_area       0
# exter_qual         0
# exter_cond         0
# foundation         0
# bsmt_qual          0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       0
# bsmtfin_type_2     0
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         0
# ...

# %% [markdown]
# ## Exploring and Fixing Data Types

# %%
df_train.head()
# Out:
#            pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# Id
# 109  533352170           60        RL           0.0     13517   Pave    NA
# 544  531379050           60        RL          43.0     11492   Pave    NA
# 153  535304180           20        RL          68.0      7922   Pave    NA
# 318  916386060           60        RL          73.0      9802   Pave    NA
# 255  906425045           50        RL          82.0     14235   Pave    NA
#
#     lot_shape land_contour utilities lot_config land_slope neighborhood  \
# Id
# 109       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 544       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 153       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 318       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 255       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df_train.dtypes
# Out:
# pid                  int64
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# roof_style          object
# roof_matl           object
# exterior_1st        object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_qual           object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# ...

# %% [markdown]
# #### MS SubClass

# %% [markdown]
# At first glance, the key change to make in the data types is converting the MS SubClass from an integer to a string/object - this is because the numbers are simply identifiers and there is no implication of strength correlated to home price with the figures.

# %%
# code to convert MS SubClass to string
df_train['ms_subclass'] = df_train.loc[:, 'ms_subclass'].map(lambda value : str(value))
df_test['ms_subclass'] = df_test.loc[:, 'ms_subclass'].map(lambda value : str(value))

# %% [markdown]
# #### PID

# %% [markdown]
# Additionally, I feel comfortable dropping the Integer column PID - that is not going to be predictive to the SalePrife as it is imply an identifier

# %%
# code to drop PID column
df_train.drop(columns = 'pid', inplace = True)
df_test.drop(columns = 'pid', inplace = True)

# %% [markdown]
# ## Numerical Values: Outliers and Others

# %% [markdown]
# #### Above Ground Living Area

# %%
df_train.sort_values('gr_liv_area', ascending = False).head()
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 1499          60        RL         313.0     63887   Pave    NA       IR3
# 2181          20        RL         128.0     39290   Pave    NA       IR1
# 1498          20        RL         123.0     47007   Pave    NA       IR1
# 2738          75        RL          60.0     19800   Pave    NA       Reg
# 2667          75        RM          90.0     22950   Pave    NA       IR2
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 1499          Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 2181          Bnk    AllPub     Inside        Gtl      Edwards        Norm
# 1498          Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 2738          Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 2667          Lvl    AllPub     Inside        Gtl      OldTown      Artery
#
# ...

# %%
df_test.sort_values('gr_liv_area', ascending = False).head()
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 2182          60        RL         130.0     40094   Pave    NA       IR1
# 1761          60        RL         160.0     15623   Pave    NA       IR1
# 1768          60        RL         104.0     21535   Pave    NA       IR1
# 2446          60        RL         118.0     35760   Pave    NA       IR1
# 1538          50        RL           0.0     14100   Pave    NA       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 2182          Bnk    AllPub     Inside        Gtl      Edwards        PosN
# 1761          Lvl    AllPub     Corner        Gtl      NoRidge        Norm
# 1768          Lvl    AllPub     Corner        Gtl      NoRidge        Norm
# 2446          Lvl    AllPub    CulDSac        Gtl      NoRidge        Norm
# 1538          Lvl    AllPub     Inside        Mod      Crawfor        Norm
#
# ...

# %%
plt.scatter(df_train['gr_liv_area'], df_train['saleprice']);
plt.xlabel('gr_liv_area');
plt.ylabel('sale_price');
plt.title('Train Data: Sale Price vs. Gr Liv Area');

# %% [markdown]
# We see here that homes with over 4,000 square feet of living are not predictive for the sale price - we decide to remove these.

# %%
mask = df_train['gr_liv_area'] <= 4000
df_train = df_train[mask]
# note that this does not need to be done for test data since we are training models on train data

# %% [markdown]
# #### Lot Frontage

# %%
df_train.sort_values('lot_frontage')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 109           60        RL           0.0     13517   Pave    NA       IR1
# 579           20        RL           0.0      9991   Pave    NA       IR1
# 2257         120        RM           0.0      9763   Pave    NA       IR1
# 2075          20        RL           0.0     17541   Pave    NA       IR1
# 104          160        FV           0.0      2403   Pave    NA       IR1
# ...          ...       ...           ...       ...    ...   ...       ...
# 1631          20        RL         160.0     18160   Grvl    NA       Reg
# 496           60        RL         174.0     15138   Pave    NA       IR1
# 1639         190        RL         195.0     41600   Pave    NA       IR1
# 2279          20        RL         200.0     43500   Pave    NA       Reg
# 1266          20        RL         313.0     27650   Pave    NA       IR2
#
# ...

# %% [markdown]
# Lot Frontage figures are acceptable.

# %% [markdown]
# #### Lot Area

# %%
df_train.sort_values('lot_area', ascending = False).head(8)
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 2116          50        RL           0.0    159000   Pave    NA       IR2
# 2072          20        RL           0.0    115149   Pave    NA       IR2
# 2767          20        RL          62.0     70761   Pave    NA       IR1
# 315           20        RL           0.0     57200   Pave    NA       IR1
# 16            60        RL          47.0     53504   Pave    NA       IR2
# 1403          20        RL           0.0     53227   Pave    NA       IR1
# 2117          60        RL           0.0     53107   Pave    NA       IR2
# 1638          20        RL          52.0     51974   Pave    NA       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 2116          Low    AllPub    CulDSac        Sev      ClearCr        Norm
# 2072          Low    AllPub    CulDSac        Sev      ClearCr        Norm
# ...

# %%
plt.figure(figsize = (7, 7));
plt.scatter(df_train['lot_area'], df_train['saleprice']);
plt.xlabel('Lot Area (SqFt)');
plt.ylabel('Sale Price ($)');

# %% [markdown]
# We note that this issue with lot area outliers will be resolved later as its impact on the model was unexpected in that taking out the outliers somewhat worsened the model.

# %% [markdown]
# #### Overall Quality and Condition

# %%
df_train.sort_values('overall_qual')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 766           30        RL           0.0     10020   Pave    NA       IR1
# 2904          20   A (agr)         125.0     31250   Pave    NA       Reg
# 1902          20        RL          50.0      5000   Pave    NA       Reg
# 1554          20   A (agr)          80.0     14584   Pave    NA       Reg
# 709           30        RM          50.0      5925   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 1321          75        RM          75.0     13500   Pave    NA       Reg
# 1764          20        RL           0.0     11400   Pave    NA       Reg
# 2331          60        RL          60.0     18062   Pave    NA       IR1
# 2337          60        RL          66.0     13682   Pave    NA       IR2
# 2276          20        RL          85.0     12633   Pave    NA       IR1
#
# ...

# %%
df_train.sort_values('overall_cond')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 766           30        RL           0.0     10020   Pave    NA       IR1
# 1306          20        RM         103.0     12205   Pave    NA       Reg
# 754           90        RM          50.0      3000   Pave  Grvl       Reg
# 2044          50        RM          60.0     10320   Pave  Grvl       Reg
# 131           30        RL          55.0      5350   Pave    NA       IR1
# ...          ...       ...           ...       ...    ...   ...       ...
# 1951          70        RL          60.0     10800   Pave  Grvl       Reg
# 1665          60        RL           0.0      7472   Pave    NA       IR1
# 722           70        RM          50.0      9000   Pave    NA       Reg
# 296           70        RL          66.0      9042   Pave    NA       Reg
# 1307          75        RM          87.0     18386   Pave    NA       Reg
#
# ...

# %%
df_test.sort_values('overall_qual')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 743           30        RM          51.0      6120   Pave    NA       Reg
# 1322          70        RM          60.0     11340   Pave    NA       Reg
# 1303          20        RM          62.0      7311   Pave    NA       Reg
# 663           30        RL          90.0      5400   Pave    NA       Reg
# 175           50        RM          60.0      5790   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 1768          60        RL         104.0     21535   Pave    NA       IR1
# 2182          60        RL         130.0     40094   Pave    NA       IR1
# 433           20        RL         105.0     13693   Pave    NA       Reg
# 431           20        RL          94.0     12220   Pave    NA       Reg
# 1761          60        RL         160.0     15623   Pave    NA       IR1
#
# ...

# %%
df_test.sort_values('overall_cond')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 214           70   C (all)           0.0      6449   Pave    NA       IR1
# 1322          70        RM          60.0     11340   Pave    NA       Reg
# 1611          70   I (all)           0.0     56600   Pave    NA       IR1
# 292           50        RL          51.0      9839   Pave    NA       Reg
# 18            20        RL          88.0     11394   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 1931          20        RL          60.0     11556   Pave    NA       Reg
# 1315          70        RM          60.0      6000   Pave  Grvl       Reg
# 575           20        RL           0.0     14694   Pave    NA       IR1
# 186           70        RM          50.0      9000   Pave  Grvl       Reg
# 1540          50        RL          70.0     12392   Pave    NA       Reg
#
# ...

# %% [markdown]
# All values are properly between 1 and 10

# %% [markdown]
# #### Year Built

# %%
df_train.sort_values('year_built')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 1319          70        RM          50.0      5250   Pave  Pave       Reg
# 216           50        RL          54.0      6342   Pave    NA       Reg
# 1998          75        RM          75.0     13500   Pave  Grvl       Reg
# 1307          75        RM          87.0     18386   Pave    NA       Reg
# 1996          70        RM          90.0      9900   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 568          160        FV          30.0      3000   Pave  Pave       Reg
# 517           20        FV          75.0      7862   Pave    NA       IR1
# 522           20        FV          85.0      9187   Pave    NA       Reg
# 819           20        RL          84.0     10933   Pave    NA       Reg
# 105           20        FV          57.0     12853   Pave  Pave       IR1
#
# ...

# %%
df_test.sort_values('year_built')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 717           70        RM          65.0     11700   Pave  Pave       IR1
# 2648          70        RM          50.0      9000   Pave  Grvl       Reg
# 720           70        RM         121.0     17671   Pave  Grvl       Reg
# 1980          30        RM          60.0     10800   Pave  Grvl       Reg
# 186           70        RM          50.0      9000   Pave  Grvl       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 447           20        RL          79.0      9541   Pave    NA       IR1
# 252           20        RL          94.0     10402   Pave    NA       IR1
# 46           120        RL          44.0      6371   Pave    NA       IR1
# 253           20        RL          64.0      7360   Pave    NA       Reg
# 18            20        RL          88.0     11394   Pave    NA       Reg
#
# ...

# %% [markdown]
# These figures are acceptable.

# %% [markdown]
# #### Year Remodeled

# %%
df_train.sort_values('year_remod/add')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 1515          30        RL          45.0      8248   Pave  Grvl       Reg
# 2088          50        RL          50.0      7550   Pave    NA       Reg
# 1996          70        RM          90.0      9900   Pave    NA       Reg
# 1976          50        RM          50.0      6000   Pave  Grvl       Reg
# 1314          75        RM          60.0      9600   Pave  Grvl       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 37            60        RL         102.0     12858   Pave    NA       IR1
# 68            20        FV          92.0      9215   Pave    NA       Reg
# 319           60        RL          92.0     12003   Pave    NA       Reg
# 45            20        RL         100.0     12919   Pave    NA       IR1
# 89            20        RL           0.0      6897   Pave    NA       IR1
#
# ...

# %%
df_test.sort_values('year_remod/add')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 2658         190        RM          69.0      9142   Pave  Grvl       Reg
# 2855          70        RL          54.0      7588   Pave    NA       Reg
# 712           30        RM          60.0      8520   Pave    NA       Reg
# 1958          20        RL          60.0     11664   Pave    NA       Reg
# 704           50        RM          56.0     10134   Pave  Grvl       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 40            20        RL          94.0     12883   Pave    NA       IR1
# 46           120        RL          44.0      6371   Pave    NA       IR1
# 39            20        RL          83.0     10159   Pave    NA       IR1
# 18            20        RL          88.0     11394   Pave    NA       Reg
# 253           20        RL          64.0      7360   Pave    NA       Reg
#
# ...

# %% [markdown]
# These figures are acceptable.

# %% [markdown]
# #### Month Sold

# %%
df_train.sort_values('mo_sold')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 1553          50        RM          75.0      9000   Pave    NA       Reg
# 1415         190        RL          70.0      7000   Pave    NA       Reg
# 2248          85        RL           0.0     12150   Pave    NA       IR1
# 1832          20        RL          43.0     12712   Pave    NA       IR1
# 908           30        RL          60.0      8400   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 1138          60        RL          65.0      8366   Pave    NA       IR1
# 660           30        RL          60.0     10230   Pave  Grvl       Reg
# 2290         180        RM          21.0      1936   Pave    NA       Reg
# 840           20        RL          65.0     14753   Pave    NA       IR2
# 1194          20        RL          72.0      8872   Pave    NA       Reg
#
# ...

# %%
df_test.sort_values('mo_sold')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 1154          20        RL          60.0      6360   Pave    NA       Reg
# 2494          20        RL           0.0     13052   Pave    NA       IR1
# 2281          20        RL          94.0     25286   Pave    NA       Reg
# 211           50        RL          72.0     10632   Pave    NA       IR1
# 1478          20        RL          85.0     11049   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 1678         160        RM          21.0      2058   Pave    NA       Reg
# 1543         160        RM          24.0      1879   Pave    NA       Reg
# 2822          20        RL          73.0     16133   Pave    NA       Reg
# 2582          90        RL           0.0      7032   Pave    NA       IR1
# 2035          50        RM          50.0      9000   Pave    NA       Reg
#
# ...

# %% [markdown]
# These figures are all properly between 1 and 12.

# %% [markdown]
# #### Year Sold

# %%
df_train.sort_values('yr_sold')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 2914         180        RM          21.0      1470   Pave    NA       Reg
# 2644          30        RM          70.0      5684   Pave    NA       Reg
# 2774          20        RL          70.0      9100   Pave    NA       Reg
# 2624          20        RL          70.0      7560   Pave    NA       Reg
# 2906         120        RM          32.0      4500   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 272           20        RL          70.0      8400   Pave    NA       Reg
# 209           70        RL           0.0     24090   Pave    NA       Reg
# 1             20        RL         141.0     31770   Pave    NA       IR1
# 192           50        RM          53.0      5830   Pave    NA       Reg
# 10            60        RL          60.0      7500   Pave    NA       Reg
#
# ...

# %%
df_test.sort_values('yr_sold')
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 2658         190        RM          69.0      9142   Pave  Grvl       Reg
# 2605         190        RL          60.0     10800   Pave    NA       Reg
# 2447          60        RL           0.0      9233   Pave    NA       IR1
# 2656          20        RM          49.0      5820   Pave    NA       Reg
# 2869          20        RL          80.0     12984   Pave    NA       Reg
# ...          ...       ...           ...       ...    ...   ...       ...
# 103          160        FV          24.0      2572   Pave    NA       Reg
# 167           20        RL          81.0      7635   Pave    NA       IR1
# 88            20        RL          75.0      7500   Pave    NA       Reg
# 290           30        RL           0.0      7890   Pave    NA       Reg
# 27            20        RL          70.0      8400   Pave    NA       Reg
#
# ...

# %% [markdown]
# These values are acceptable for now.

# %% [markdown]
# # 4. Initial Data Analysis

# %% [markdown]
# ## Initial EDA

# %%
df_train.describe()
# Out:
#        lot_frontage       lot_area  overall_qual  overall_cond   year_built  \
# count   2049.000000    2049.000000   2049.000000   2049.000000  2049.000000
# mean      57.785749   10024.677892      6.108346      5.562714  1971.673499
# std       32.633866    6608.511749      1.421780      1.104897    30.171293
# min        0.000000    1300.000000      1.000000      1.000000  1872.000000
# 25%       43.000000    7500.000000      5.000000      5.000000  1953.000000
# 50%       63.000000    9405.000000      6.000000      5.000000  1974.000000
# 75%       78.000000   11500.000000      7.000000      6.000000  2001.000000
# max      313.000000  159000.000000     10.000000      9.000000  2010.000000
#
#        year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  bsmt_unf_sf  \
# count     2049.000000   2049.000000   2049.000000   2049.000000  2049.000000
# mean      1984.166423     97.736945    437.804783     47.982430   567.248414
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049 entries, 109 to 10
# Data columns (total 78 columns):
# ms_subclass        2049 non-null object
# ms_zoning          2049 non-null object
# lot_frontage       2049 non-null float64
# lot_area           2049 non-null int64
# street             2049 non-null object
# alley              2049 non-null object
# lot_shape          2049 non-null object
# land_contour       2049 non-null object
# utilities          2049 non-null object
# lot_config         2049 non-null object
# land_slope         2049 non-null object
# neighborhood       2049 non-null object
# condition_1        2049 non-null object
# condition_2        2049 non-null object
# bldg_type          2049 non-null object
# house_style        2049 non-null object
# overall_qual       2049 non-null int64
# overall_cond       2049 non-null int64
# year_built         2049 non-null int64
# year_remod/add     2049 non-null int64
# roof_style         2049 non-null object
# ...

# %% [markdown]
# # 5. Feature Engineering

# %% [markdown]
# ### Dummy Variables

# %%
# below is confirming the list of nominal features to make into dummies
features_dict['nominal']
# Out:
# ['ms_subclass',
#  'ms_zoning',
#  'street',
#  'alley',
#  'land_contour',
#  'lot_config',
#  'neighborhood',
#  'condition_1',
#  'condition_2',
#  'bldg_type',
#  'house_style',
#  'roof_style',
#  'roof_matl',
#  'exterior_1st',
#  'exterior_2nd',
#  'mas_vnr_type',
#  'foundation',
#  'heating',
#  'central_air',
#  'garage_type',
#  'sale_type']

# %%
# dummy all nominal features
df_train_dummies = pd.get_dummies(df_train[features_dict['nominal']])
df_test_dummies = pd.get_dummies(df_test[features_dict['nominal']])

# %%
# list of new test columns (have to exclude Sale Price)
df_dummies_test_new_cols = list(set(df_train_dummies.columns) - set(df_test_dummies.columns))

df_dummies_test_new_cols
# Out:
# ['exterior_1st_ImStucc',
#  'exterior_1st_Stone',
#  'ms_subclass_150',
#  'neighborhood_Landmrk',
#  'condition_2_Artery',
#  'heating_Wall',
#  'ms_zoning_A (agr)',
#  'heating_OthW',
#  'exterior_2nd_Stone',
#  'exterior_1st_CBlock',
#  'condition_2_RRAn',
#  'roof_matl_Membran',
#  'neighborhood_GrnHill',
#  'condition_2_RRNn',
#  'condition_2_RRAe']

# %%
# list of new train cols
df_train_new_cols = list(set(df_test_dummies.columns) - set(df_train_dummies.columns))
df_train_new_cols
# Out:
# ['heating_Floor',
#  'exterior_2nd_PreCast',
#  'exterior_2nd_Other',
#  'exterior_1st_PreCast',
#  'sale_type_VWD',
#  'roof_matl_Metal',
#  'mas_vnr_type_CBlock',
#  'roof_matl_Roll']

# %%
# adding new dummy columns to test with value 0
for col in df_dummies_test_new_cols:
    df_test_dummies[col] = 0

# %%
# adding new dummy columns to train with value 0
for col in df_train_new_cols:
    df_train_dummies[col] = 0

# %%
list(set(df_train_dummies.columns) - set(df_test_dummies.columns))
# Out:
# []

# %% [markdown]
# We now have dummies list with all dummies for nominal features.  However, we now need to simulate the drop first method in the get dummies function.

# %%
features_dict['nominal']
# Out:
# ['ms_subclass',
#  'ms_zoning',
#  'street',
#  'alley',
#  'land_contour',
#  'lot_config',
#  'neighborhood',
#  'condition_1',
#  'condition_2',
#  'bldg_type',
#  'house_style',
#  'roof_style',
#  'roof_matl',
#  'exterior_1st',
#  'exterior_2nd',
#  'mas_vnr_type',
#  'foundation',
#  'heating',
#  'central_air',
#  'garage_type',
#  'sale_type']

# %%
df_train_dummies.shape
# Out:
# (2049, 177)

# %%
dum_dict = {}
for feature in features_dict['nominal']:
    dum_dict[feature] = []
    for col in df_train_dummies.columns:
        if feature in col:
            dum_dict[feature].append(col)

# %%
for key in dum_dict:
    df_train_dummies.drop(columns = dum_dict[key][0], inplace = True)
    df_test_dummies.drop(columns = dum_dict[key][0], inplace = True)

# %% [markdown]
# We can now merge our dummies columns with our data frames and drop the nominal features columns.

# %%
df_train = df_train.merge(df_train_dummies, on = 'Id')
df_test = df_test.merge(df_test_dummies, on = 'Id')

# %%
df_train.drop(columns = features_dict['nominal'], inplace = True)
df_test.drop(columns = features_dict['nominal'], inplace = True)

# %%
df_train.shape
# Out:
# (2049, 213)

# %%
df_test.shape
# Out:
# (879, 212)

# %% [markdown]
# ### Ordinal Features

# %%
features_dict['ordinal']
# Out:
# ['lot_shape',
#  'utilities',
#  'land_slope',
#  'overall_qual',
#  'overall_cond',
#  'exter_qual',
#  'exter_cond',
#  'bsmt_qual',
#  'bsmt_cond',
#  'bsmt_exposure',
#  'bsmtfin_type_1',
#  'bsmtfin_type_2',
#  'heating_qc',
#  'electrical',
#  'kitchen_qual',
#  'functional',
#  'fireplace_qu',
#  'garage_finish',
#  'garage_qual',
#  'garage_cond',
#  'paved_drive',
#  'pool_qc',
#  'fence']

# %%
# creating dict so we can assign numbers to our ordinal values
dict_ord = { 'lot_shape': {'IR1': 3,'IR2': 2, 'IR3': 1,'Reg': 4},
            'utilities': {'ELO': 1, 'NoSeWa': 2, 'NoSewr': 3, 'AllPub':4},
            'land_slope': {'Sev': 1, 'Mod': 2, 'Gtl': 3},
            'exter_qual': {'Po': 1 , 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
            'exter_cond': {'Po': 1 , 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
            'bsmt_qual': {'NA': 1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6},
            'bsmt_cond': {'NA': 1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6},
            'bsmt_exposure': {'NA': 1, 'No': 2, 'Mn': 3, 'Av':4, 'Gd':5 },
            'bsmtfin_type_1': {'NA':1, 'Unf':2, 'LwQ':3, 'Rec':4, 'BLQ':5, 'ALQ':6, 'GLQ': 7},
            'bsmtfin_type_2': {'NA':1, 'Unf':2, 'LwQ':3, 'Rec':4, 'BLQ':5, 'ALQ':6, 'GLQ': 7},
            'heating_qc': {'Po': 1 , 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
            'electrical': {'Mix':1, 'FuseP': 2, 'FuseF':3, 'FuseA':4, 'SBrkr':5},
            'kitchen_qual': {'Po': 1 , 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
            'functional': {'Sal':1, 'Sev':2, 'Maj2':3, 'Maj1':4, 'Mod':5, 'Min2':6, 'Min1': 7, 'Typ':8},
            'fireplace_qu': {'NA': 1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6},
            'garage_finish': {'NA': 1,'Unf':2, 'RFn':3, 'Fin':4},
            'garage_qual': {'NA': 1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6},
            'garage_cond': {'NA': 1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6},
            'paved_drive': {'N':1, 'P':2, 'Y': 3},
            'pool_qc': {'NA': 1,'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
            'fence': {'NA': 1 , 'MnWw': 2, 'GdWo':3, 'MnPrv':4, 'GdPrv':5}
           }

# %%
df_train.head()
# Out:
#      lot_frontage  lot_area lot_shape utilities land_slope  overall_qual  \
# Id
# 109           0.0     13517       IR1    AllPub        Gtl             6
# 544          43.0     11492       IR1    AllPub        Gtl             7
# 153          68.0      7922       Reg    AllPub        Gtl             5
# 318          73.0      9802       Reg    AllPub        Gtl             5
# 255          82.0     14235       IR1    AllPub        Gtl             6
#
#      overall_cond  year_built  year_remod/add  mas_vnr_area exter_qual  \
# Id
# 109             8        1976            2005         289.0         Gd
# 544             5        1996            1997         132.0         Gd
# 153             7        1953            2007           0.0         TA
# 318             5        2006            2007           0.0         TA
# 255             8        1900            1993           0.0         TA
#
#     exter_cond bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# Id
# ...

# %%
df_test['bsmt_cond'].unique()
# Out:
# array(['TA', 'Gd', 'NA', 'Fa'], dtype=object)

# %%
df_train['bsmt_cond'].unique()
# Out:
# array(['TA', 'Gd', 'NA', 'Fa', 'Po', 'Ex'], dtype=object)

# %%
df_train.replace(dict_ord, inplace = True)
df_test.replace(dict_ord, inplace = True)

# %%
df_train['bsmt_cond'].dtypes
# Out:
# dtype('int64')

# %%
df_test['bsmt_cond'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# We noticed an error in the data cleaining and need to convert some columns to the proper data types

# %%
df_test['bsmt_cond'].unique()
# Out:
# array([4, 5, 1, 3], dtype=object)

# %%
df_test['bsmt_cond'] = df_test['bsmt_cond'].map(lambda x: int(x))

# %%
df_test['garage_qual'] = df_test['garage_qual'].map(lambda x: int(x))

# %%
df_test['bsmt_cond'] = df_test['bsmt_cond'].map(lambda x : int(x))

# %% [markdown]
# We are now at the point where all possible features are numeric and can be run as inputs in our model.

# %% [markdown]
# ### Interaction Features and Other Additions/Subtractions

# %% [markdown]
# First off, I want to create an interaction feature between the overall quality and then the condition.  I believe this may have a compounding effect.

# %%
df_train['qual_cond_interaction'] = df_train['overall_qual'] * df_train['overall_cond']
df_test['qual_cond_interaction'] = df_test['overall_qual'] * df_test['overall_cond']

# %% [markdown]
# Second, instead of a feature called year built, I want to have a column with the age of the building.  We will follow the same for remodeling and garage. We will assume it is currently 2011 as our most recent home sale is 2010.

# %%
df_train['home_age'] = 2011 - df_train['year_built']
df_test['home_age'] = 2011 - df_test['year_built']
df_train['remod_age'] = 2011 - df_train['year_remod/add']
df_test['remod_age'] = 2011 - df_test['year_remod/add']
df_train['garage_age'] = 2011 - df_train['garage_yr_blt']
df_test['garage_age'] = 2011 - df_test['garage_yr_blt']
df_train.drop(columns = ['year_built', 'year_remod/add', 'garage_yr_blt'], inplace = True)
df_test.drop(columns = ['year_built', 'year_remod/add', 'garage_yr_blt'], inplace = True)

# %%
df_train.head()
# Out:
#      lot_frontage  lot_area  lot_shape  utilities  land_slope  overall_qual  \
# Id
# 109           0.0     13517          3          4           3             6
# 544          43.0     11492          3          4           3             7
# 153          68.0      7922          4          4           3             5
# 318          73.0      9802          4          4           3             5
# 255          82.0     14235          3          4           3             6
#
#      overall_cond  mas_vnr_area  exter_qual  exter_cond  bsmt_qual  bsmt_cond  \
# Id
# 109             8         289.0           4           3          4          4
# 544             5         132.0           4           3          5          4
# 153             7           0.0           3           4          4          4
# 318             5           0.0           3           3          5          4
# 255             8           0.0           3           3          3          5
#
# ...

# %% [markdown]
# Similar to overall quality, we see features for basement quality and condition.  We should make an interaction variable for this.

# %%
df_train['bsmt_qual_cond_interaction'] = df_train['bsmt_qual'] * df_train['bsmt_cond']
df_test['bsmt_qual_cond_interaction'] = df_test['bsmt_qual'] * df_test['bsmt_cond']
df_train['garage_qual_cond_interaction'] = df_train['garage_qual'] * df_train['garage_cond']
df_test['garage_qual_cond_interaction'] = df_test['garage_qual'] * df_test['garage_cond']

# %% [markdown]
# # 6.  Correlations & Additional Feature Engineering

# %% [markdown]
# ## Correlation Heat Maps

# %% [markdown]
# First, we want to see correlations with Sale Price and all discrete variables

# %%
# large correlation map to take a quick look at features that have a strong correlation with sale price
plt.figure(figsize = (2, 30))
sns.heatmap(df_train.corr()[['saleprice']].sort_values('saleprice', ascending=False),
           annot = True, cmap = 'RdBu', vmin = -1, vmax = 1)
plt.title('Overall Sale Price Correlation Map');
plt.xlabel('Sale Price');
plt.ylabel('Features');

# %% [markdown]
# ### Sale Price

# %% [markdown]
# Below is the histogram showing sales price on an unadjusted basis.  Notably, there is a pretty strong positive skew, which means that linear regression may not be the best way to predict this value.

# %%
plt.figure(figsize = (9, 8))
plt.hist(df_train['saleprice'], bins = 20, color = 'maroon');
plt.xlabel('Sale Price ($)', size = 15);
plt.ylabel('Count', size = 15);
plt.xticks(size = 14)
plt.yticks(size = 14)
plt.title('Sale Price Value Counts', size = 20);
plt.xlim([0, 650000])
plt.ylim([0, 500])
# Out:
# (0, 500)

# %% [markdown]
# However, when we plot a histogram of the value counts for the log of Sale Price, we get a more normal distribution.  Therefore, we believe it best to have log of Sale Price be our target as opposed to Sale Price on its own.

# %%
plt.hist(np.log(df_train['saleprice']), color = 'maroon');
plt.xlabel('Log Sale Price');
plt.ylabel('Count');
plt.title('Log Sale Price Value Counts', size = 14);

# %% [markdown]
# ### Lot Area

# %% [markdown]
# Quite interestingly, the Beta for lot area and sale price was quite low.

# %%
plt.figure(figsize = (9,8));
plt.scatter(df_train['lot_area'],df_train['saleprice'], color = 'maroon');
plt.title('Relationship Between Lot Area and Sale Price', size = 20)
plt.xlabel('Lot Area (SqFt)', size = 15);
plt.ylabel('Sale Price ($)', size = 15);
plt.xlim([0, 80000]);
plt.ylim([0, 700000]);
plt.xticks(size = 14);
plt.yticks(size = 14);

# %% [markdown]
# First off, we see two significant outliers.  However, removing them from our data set actually worsened our regression metrics, so we will keep them in.  Presumably, these errors helped our model become more accustomed to outliers.

# %% [markdown]
# We see another positive skew with lot area although it doesn't appear to be too impactful.  Logging this data gives us a histogram with a very strong normal distribution.

# %%
plt.figure(figsize = (9,8));
plt.hist(df_train['lot_area'], bins = 75, color = 'maroon');
plt.xlabel('Lot Area', size = 15);
plt.ylabel('Count', size = 15);
plt.xticks(size = 14)
plt.yticks(size = 14)
plt.title('Lot Area Value Counts', size = 20);
plt.xlim([0, 80000]);
plt.ylim([0, 600]);

# %%
plt.hist(np.log(df_train['lot_area']), bins = 50, color = 'maroon');
plt.xlabel('Lot Area');
plt.ylabel('Count');
plt.title('Log Lot Area Value Counts', size = 14);

# %%
df_train['lot_area'] = np.log(df_train['lot_area'])
df_test['lot_area'] = np.log(df_test['lot_area'])

# %% [markdown]
# ### Above Ground Living Area

# %% [markdown]
# Above Ground Living Area vs. Sale Price is unsuprisingly positively correlated, however, with some exponential shape. A log of the grand living area and sales price shows a strong positive, linear correlation.  We'll then make Gr Living area the log of its current value.  Further analysis shows that this works on the model.  However, we see in our training data for both lot area and grand living area, there are two big outliers. We remove those further down.

# %%
plt.figure(figsize = (9,8))
plt.scatter(df_train['gr_liv_area'],df_train['saleprice'], color = 'maroon');
plt.title('Relationship Between Living Area and Price', size = 20)
plt.xlabel('Above Ground Living Area (SqFt)', size = 15);
plt.ylabel('Sale Price', size = 15);
plt.xticks(size = 14);
plt.yticks(size = 14);
plt.xlim([0, 5000]);
plt.ylim([0, 700000]);

# %%
df_train['gr_liv_area'] = np.log(df_train['gr_liv_area'])
df_test['gr_liv_area'] = np.log(df_test['gr_liv_area'])

# %%
plt.scatter(np.log(df_train['gr_liv_area']),np.log(df_train['saleprice']), color = 'maroon');
plt.xlabel('Log Above Ground Living Area');
plt.ylabel('Log Sale Price');

# %% [markdown]
# We also see a couple of outliers that popped up in our overview of Lot Area.  However, removing these actually hurt our scores, so we will keep them in.

# %% [markdown]
# ### Neighborhood Analysis

# %% [markdown]
# Next we want to look at average sale price by neighborhood to see if we find anything interesting.

# %%
neighborhood_list = []
for col in df_train:
    if 'neighborhood' in col:
        neighborhood_list.append(col)

# %%
neighborhood_mean_prices = []

for neighborhood in neighborhood_list:
    neighborhood_mean_prices.append(df_train[df_train[neighborhood] == 1]['saleprice'].mean())

# %% [markdown]
# ### Home Quality Analysis

# %% [markdown]
# I wanted to see if the relationship between our engineered home quality and condition variable was in fact positively correlated with log of sale price.  There is in fact some kind of positive, linear relationship between the two variables.  However, this does tail off toward the end which explains why this variable does not rate quite so high when we look at its beta coefficient. Giving away a conclusion to our problem, we continue to see that our model might do better when looking at homes for middle class individuals.

# %%
plt.figure(figsize = (9,8))
plt.scatter(df_train['qual_cond_interaction'],df_train['saleprice'], color = 'maroon');
plt.title('Relationship Between Quality/Cond and Sale Price', size = 20)
plt.xlabel('Quality/Condition Interaction', size = 15);
plt.ylabel('Sale Price', size = 15);
plt.xticks(size = 14);
plt.yticks(size = 14);
plt.xlim([0, 100]);
plt.ylim([0, 700000]);

# %% [markdown]
# # 7. Modeling

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# This is a simple linear regresssion taking all features as inputs to identify any interesting trends with the coefficients before moving forward with additional feature engineering.

# %%
# setting features for stronger correlated features
features = [i for i in df_train if df_train[i].corr(df_train['saleprice']) > 0.3 or df_train[i].corr(df_train['saleprice']) < -0.3]
features.remove('saleprice')

# setting X and y variables
X = df_train[features]
y = np.log(df_train['saleprice'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 22)

# %%
#instantiate model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(X_train, y_train)
# Out:
# 0.9066866078936167

# %%
lr.score(X_test, y_test)
# Out:
# 0.8933180422762217

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()
# Out:
# 0.901524519649563

# %%
lr_train_preds = np.exp(lr.predict(X_train))
lr_test_preds = np.exp(lr.predict(X_test))

# %%
print(f'Model 1 Train RMSE: {np.sqrt(mean_squared_error(np.exp(y_train), lr_train_preds))}')
print(f'Model 1 Test RMSE: {np.sqrt(mean_squared_error(np.exp(y_test), lr_test_preds))}')
# Out:
# Model 1 Train RMSE: 21811.9932958361
# Model 1 Test RMSE: 21541.222462616217

# %% [markdown]
# ### Error Regression Plot

# %%
#### resids = np.exp(y_test) - lr_test_preds
plt.figure(figsize = [26, 14]);
plt.scatter(np.exp(y_test), resids, color = 'maroon');
plt.axhline(0, color = 'red');
plt.axvline(200000, color = 'blue')
plt.xlabel('Testing Set Sale Prices', size = 25);
plt.ylabel('Residuals', size = 25);
plt.title('Linear Regression Residual Plot', size = 40);
plt.xticks(size = 20);
plt.yticks(size = 20);

# %% [markdown]
# ### Beta Coefficient Analysis

# %%
df_coef = pd.DataFrame(lr.coef_)
df_coef['name'] = X.columns
df_coef['abs_coef'] = np.abs(df_coef[0])
df_coef.sort_values(by = 'abs_coef', ascending = False)
# Out:
#                0                        name      abs_coef
# 11  4.261503e-01                 gr_liv_area  4.261503e-01
# 0   1.093069e-01                    lot_area  1.093069e-01
# 32  7.492671e-02               sale_type_New  7.492671e-02
# 23  4.077071e-02        neighborhood_NridgHt  4.077071e-02
# 25 -3.828642e-02        exterior_2nd_VinylSd  3.828642e-02
# 26  3.411418e-02           mas_vnr_type_None  3.411418e-02
# 29  3.345217e-02            foundation_PConc  3.345217e-02
# 31  2.843653e-02          garage_type_Detchd  2.843653e-02
# 18  2.704506e-02                 garage_cars  2.704506e-02
# 30  2.640879e-02          garage_type_Attchd  2.640879e-02
# 13  2.632607e-02                kitchen_qual  2.632607e-02
# 9   2.031085e-02                  heating_qc  2.031085e-02
# 1   2.019052e-02                overall_qual  2.019052e-02
# 22 -1.653114e-02              ms_subclass_60  1.653114e-02
# 24  1.642224e-02        exterior_1st_VinylSd  1.642224e-02
# ...

# %% [markdown]
# ## Lasso Regression

# %%
ss = StandardScaler()

z_train = ss.fit_transform(X_train)
z_test = ss.transform(X_test)

# %%
# Set up a list of Lasso alphas to check.
l_alphas = np.logspace(-3, 0, 100)

# Cross-validate over our list of Lasso alphas.
lasso = LassoCV(alphas=l_alphas, cv=5, max_iter = 5000)

# Fit model using best ridge alpha!
lasso.fit(z_train, y_train)
# Out:
# LassoCV(alphas=array([0.001     , 0.00107227, 0.00114976, 0.00123285, 0.00132194,
#        0.00141747, 0.00151991, 0.00162975, 0.00174753, 0.00187382,
#        0.00200923, 0.00215443, 0.00231013, 0.00247708, 0.00265609,
#        0.00284804, 0.00305386, 0.00327455, 0.00351119, 0.00376494,
#        0.00403702, 0.00432876, 0.00464159, 0.00497702, 0.0053367 ,
#        0.00572237, 0.00613591, 0.00657933, 0.0070548 , 0.00756463,
#        0.008...
#        0.37649358, 0.40370173, 0.43287613, 0.46415888, 0.49770236,
#        0.53366992, 0.57223677, 0.61359073, 0.65793322, 0.70548023,
#        0.75646333, 0.81113083, 0.869749  , 0.93260335, 1.        ]),
#         copy_X=True, cv=5, eps=0.001, fit_intercept=True, max_iter=5000,
#         n_alphas=100, n_jobs=None, normalize=False, positive=False,
#         precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#         verbose=False)

# %%
lasso.score(z_train, y_train)
# Out:
# 0.9062767074739491

# %%
lasso.score(z_test, y_test)
# Out:
# 0.894291490041735

# %%
lasso_train_preds = np.exp(lasso.predict(z_train))
lasso_test_preds = np.exp(lasso.predict(z_test))

print(f'Model 1 Train RMSE: {np.sqrt(mean_squared_error(np.exp(y_train), lasso_train_preds))}')
print(f'Model 2 Test RMSE: {np.sqrt(mean_squared_error(np.exp(y_test), lasso_test_preds))}')
# Out:
# Model 1 Train RMSE: 21798.175805296098
# Model 2 Test RMSE: 21260.64896141207

# %% [markdown]
# ### Error Regression Plot

# %%
resids = np.exp(y_test) - lasso_test_preds
plt.scatter(np.exp(y_test), resids, color = 'maroon');
plt.axhline(0, color = 'red');
plt.xlabel('Testing Set Sale Prices');
plt.ylabel('Residuals');
plt.title('Lasso Residual Plot', size = 14);

# %% [markdown]
# ## Ridge Regression

# %%
# Set up a list of ridge alphas to check.
# Generates 100 values equally between 0 and 5,
# then converts them to alphas between 10^0 and 10^5.
r_alphas = np.logspace(0, 5, 100)

# Cross-validate over our list of ridge alphas.
ridge = RidgeCV(alphas = r_alphas, scoring = 'r2', cv = 5)

# Fit model using best ridge alpha!
ridge.fit(z_train, y_train)
# Out:
# RidgeCV(alphas=array([1.00000000e+00, 1.12332403e+00, 1.26185688e+00, 1.41747416e+00,
#        1.59228279e+00, 1.78864953e+00, 2.00923300e+00, 2.25701972e+00,
#        2.53536449e+00, 2.84803587e+00, 3.19926714e+00, 3.59381366e+00,
#        4.03701726e+00, 4.53487851e+00, 5.09413801e+00, 5.72236766e+00,
#        6.42807312e+00, 7.22080902e+00, 8.11130831e+00, 9.11162756e+00,
#        1.02353102e+01, 1.14975700e+0...
#        1.09749877e+04, 1.23284674e+04, 1.38488637e+04, 1.55567614e+04,
#        1.74752840e+04, 1.96304065e+04, 2.20513074e+04, 2.47707636e+04,
#        2.78255940e+04, 3.12571585e+04, 3.51119173e+04, 3.94420606e+04,
#        4.43062146e+04, 4.97702356e+04, 5.59081018e+04, 6.28029144e+04,
#        7.05480231e+04, 7.92482898e+04, 8.90215085e+04, 1.00000000e+05]),
#         cv=5, fit_intercept=True, gcv_mode=None, normalize=False, scoring='r2',
#         store_cv_values=False)

# %%
ridge.score(z_train, y_train)
# Out:
# 0.9065474791749475

# %%
ridge.score(z_test, y_test)
# Out:
# 0.8942220262536368

# %%
ridge_train_preds = np.exp(ridge.predict(z_train))
ridge_test_preds = np.exp(ridge.predict(z_test))

print(f'Model 1 Train RMSE: {np.sqrt(mean_squared_error(np.exp(y_train), ridge_train_preds))}')
print(f'Model 2 Test RMSE: {np.sqrt(mean_squared_error(np.exp(y_test), ridge_test_preds))}')
# Out:
# Model 1 Train RMSE: 21750.501629662085
# Model 2 Test RMSE: 21405.030564608987

# %% [markdown]
# ### Error Regression Plot

# %%
resids = np.exp(y_test) - ridge_test_preds
plt.scatter(np.exp(y_test), resids, color = 'maroon');
plt.axhline(0, color = 'red');
plt.xlabel('Testing Set Sale Prices');
plt.ylabel('Residuals');
plt.title('Ridge Residual Plot', size = 14);

# %% [markdown]
# ### Baseline Model

# %%
# instantiate baseline model that predicts the mean of the data every time
base_model = DummyRegressor(strategy = 'mean')

# Fit model
base_model = base_model.fit(X_train, y_train)

# get predictions
base_train_preds = np.exp(base_model.predict(X_train))
base_test_preds = np.exp(base_model.predict(X_test))

# Evaluate: Let's use RMSE

print(f'Baseline model Train RMSE: {np.sqrt(mean_squared_error(np.exp(y_train), base_train_preds))}')
print(f'Baseline model Test RMSE: {np.sqrt(mean_squared_error(np.exp(y_test), base_test_preds))}')
# Out:
# Baseline model Train RMSE: 80529.88966809193
# Baseline model Test RMSE: 81076.55670733476

# %% [markdown]
# We decided to choose a baseline model where each prediction is the mean of our target variable.  This does show that our models are fairly predictive.

# %% [markdown]
# ### Final Model Selection

# %% [markdown]
# Ultimately, all of my models performed similarly well and there is not much to differentiate them given that R^2 scores and Root Mean Squared Errors are roughly in line.  Therefore, I will select the Linear Regression model given that it is easier to discuss to a broader range of audiences

# %% [markdown]
# #### Kaggle Submission

# %%
X_kaggle = df_test[features]

# %%
X_kaggle['SalePrice'] = np.exp(lr.predict(X_kaggle))
# Out:
# /Users/nick_cote/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_kaggle.head()
# Out:
#       lot_area  overall_qual  mas_vnr_area  exter_qual  bsmt_qual  \
# Id
# 2658  9.120634             6           0.0           3          3
# 2718  9.175956             5           0.0           3          5
# 2414  9.747068             7           0.0           4          5
# 1989  9.050172             5           0.0           4          4
# 625   9.159047             6         247.0           3          5
#
#       bsmt_exposure  bsmtfin_type_1  bsmtfin_sf_1  total_bsmt_sf  heating_qc  \
# Id
# 2658              2               2             0           1020           4
# 2718              2               2             0           1967           3
# 2414              4               7           554            654           5
# 1989              2               2             0            968           3
# 625               2               5           609           1394           4
#
#       1st_flr_sf  gr_liv_area  full_bath  kitchen_qual  totrms_abvgrd  \
# Id
# ...

# %%
output = X_kaggle[['SalePrice']]

# %%
# this is updated at every submission and as such is commented out
# output.to_csv('../datasets/my_11_submission.csv')

# %% [markdown]
# # 8. Conclusions and Recommendation

# %% [markdown]
# My problem statement is ultimately, what are the factors driving home price in this data set?  How can prospective home buyers take advantage of this information?  And lastly, where can we take this model from here?
#
# To begin with, we would like to restate some ideas behind my model.  First of all, the target variable is a log of the sale price, not the sale price itself.  We noticed that the sale prices follow a distribution with a positive skew on their own; after taking a log of the price, we find the prices following a normal distribution.  Moreover, we took a log of the above ground living area as this follows the same distribution as the sale prices.  Finally, I looked at including features with varying degrees of correlation with sales price and ultimately found that our best model that had the best fit along the bias/variance tradeoff included features with a more than 0.3 or less than -0.3 R^2 value with the sale price.  Ultimately, all of my models performed similarly well and there is not much to differentiate them given that R^2 scores and Root Mean Squared Errors are roughly in line between them.  Therefore, I selected the Linear Regression model given that it is easier to discuss to a broader range of audiences.
#
# Returning to the problem statment.  For the first part (regarding what factors are driving home prices), some of the answers are fairly obvious and are backed up by both visualizations of the data as well as the final coefficients of our model.  The three features with the strongest beta coefficients in our model are lot area, living area (log version), and whether or not the sale price was new.  The first two are fairly obvious and do not require much additional explanation - the bigger the property, the more expensive it is.  The third is also fairly intuitive in that newer homes are likely nicer and more in line with current trends.  High up on this list of factors driving home prices includes other factors that should seem fairly obvious - overall quality of the home, various internal system qualities, and certain neighborhoods.
#
# The more interesting question to us are the features that help drive the model that are not quite so obvious on the surface.  We note that some of this may be noise, but it is worth discussing.  These features include various, what I would call, style features, such as Vinyl Exterior Siding, having fireplaces, and having strong basement finishes.  Moreover, having a strong concrete foundation was heavily correlated with price.  Although this seemed odd at first, we realize this may be largely due to the regions propensity for tornadoes and as such this is not too suprising.  Additional features can be found in the coefficient analysis section of the code book.
#
# This leads us to the second question, which is how can homeowners take advantage of this?  We feel that homeowners who are willing to sacrifice certain style features are going to be able to get a strong house in terms of both size and quality may not have the most up to date or trendy features in conjunction with it.  Certainly there is a cost benefit analysis to such decision making but in terms of where this model can become useful, we feel that this is a key spot for it.
#
# Finally, where can we take our model from here?  First things first, we do realize the need to update this with new information to make forward looking decisions.  However, assuming we are able to do this, we would like to note that this model can be used to find value on the home market, and especially for middle income residents as our model is particularly accurate for these types of homes.  We would do this by noting when our model has a home price far above its listing price - it stands to reason that this may be a deal worth looking at. Second, we would look forward to seeing which coefficients that are important in our model change as time goes on - this may be an interestin way to track trends and once again, find the certain styles to avoid to drive value in other aspects of the home.
